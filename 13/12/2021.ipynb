# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj-raghav/manoj-raghav/blob/main/13/12/2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("ENETR THE MONTH NUMBER : "))
if a<=7:
  if a%2!=0 and a!=2:
    print("31 DAYS")
  elif a==2:
    b=int(input("ENTER THE YEAR :"))
    if b%4==0:
      print("29 DAYS")
    else:
      print("28 DAYS")
  else:
    print('30 DAYS')
elif a>7 and a<=12:
  if a%2==0:
    print(" 31 DAYS ")
  else :
    print("30 DAYS")
else:
  print('INVALID INPUT')
# Out:
# ENETR THE MONTH NUMBER : 2
# ENTER THE YEAR :2004
# 29 DAYS
