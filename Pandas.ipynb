# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj-raghav/manoj-raghav/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

c={1:'ENGLISH',2:'MATHS',3:'PHYSICS',4:'CHEMISTRY'}

df=pd.Series(c,index=[1,3])
print(df)
# Out:
# 1    ENGLISH
# 3    PHYSICS
# dtype: object
